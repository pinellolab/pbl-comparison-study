# %% [markdown]
# # Linear Models

# %%
import numpy as np
import pandas as pd
from patsy import dmatrix,demo_data
import pystan
import matplotlib.pyplot as plt

# %% [markdown]
# ## General Model Specification

# %% [markdown]
# Let $N$  be the number of data points $(\mathbf{X},\mathbf{y})=\{(\mathbf{x}_n, y_n)\}$. A linear model for  the data assumes a linear relationship between the inputs $\mathbf{x}\in\{0,1, \cdots, D-1\}$ and the outputs $y\in\mathbb{R}$ and has the following parameters.
#
# 1. $\beta$  model's weights.
# 2. $\sigma_{\beta}^2$ is (known) prior variance.
# 3. $\sigma_y^2$ is (known) likelihood variance.
#
# The joint distribution of the data and parameters is
#
# \begin{align*}
#  p(\mathbf{y}, \mathbf{X},\beta,\sigma_y^2,\sigma_{\beta}^2)= \text{Normal}(\beta \mid \mathbf{0}, \sigma_{\beta}^2\mathbf{I})\prod_{n=1}^N  \text{Normal}(y_n \mid \mathbf{x}_n^\top\beta , \sigma_y^2)
# \end{align*}
#
# The hierarchical model can be specified as such
#
# \begin{align*}
#   \beta
#   &\sim
#   \text{Normal}( \mathbf{0}, \sigma_{\beta}^2\mathbf{I}),
#   \\[1.5ex]
#   y_n \mid (\mathbf{x}_n, \beta)
#   &\sim
#   \text{Normal}(\mathbf{x}_n^\top\beta , \sigma_y^2)
# \end{align*}

# %% [markdown]
# ## Data

# %% [markdown]
# ### One categorical variable with one level

# %%
def build_dataset_linear_model_categorical_1(N, beta, noise_std):
  D = len(beta)
  X = dmatrix('-1+a', data=demo_data( "a", nlevels=D, min_rows=N), return_type='dataframe')
  y = np.dot(X.values, beta) + np.random.normal(0, noise_std, size=(N,1))
  return X, y

# %% [markdown]
# ## Inference

# %%
code = """
data {
  int<lower=0> N;
  vector[N] x;
  vector[N] y;
  real sigma;
}
parameters {
  real beta;
}
model {
  y ~ normal(x * beta, sigma);
}

generated quantities {
   real y_sim[N];
   for(n in 1:N) { 
    y_sim[n] = normal_rng(x[n] * beta, sigma);
   }
}

"""

dat = {'N': N,
       'sigma': noise_std,
       'x': list(df_train['a[a1]'].values),
       'y': list(df_train['y'].values)}

sm = pystan.StanModel(model_code=code)
fit = sm.sampling(data=dat, iter=1000, chains=4)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_f176826d5bad4df6571b1cb348cf7351 NOW.
# /home/rick/anaconda3/envs/tensorflow/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
print(fit)
# Out:
# Inference for Stan model: anon_model_f176826d5bad4df6571b1cb348cf7351.
# 4 chains, each with iter=1000; warmup=500; thin=1;
# post-warmup draws per chain=500, total post-warmup draws=2000.
#
#             mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# beta         3.0  3.8e-4   0.01   2.98   2.99    3.0    3.0   3.02    725    1.0
# y_sim[0]     3.0  2.3e-3    0.1    2.8   2.93    3.0   3.07    3.2   2000    1.0
# y_sim[1]    2.99  2.4e-3    0.1    2.8   2.92   2.99   3.06    3.2   1734    1.0
# y_sim[2]    2.99  2.5e-3    0.1    2.8   2.93   2.99   3.06   3.18   1631    1.0
# y_sim[3]     3.0  2.3e-3    0.1    2.8   2.93    3.0   3.07   3.21   2000    1.0
# y_sim[4]     3.0  2.3e-3    0.1    2.8   2.92   2.99   3.07    3.2   1993    1.0
# y_sim[5]     3.0  2.3e-3    0.1    2.8   2.93   2.99   3.06    3.2   2000    1.0
# y_sim[6]     3.0  2.2e-3    0.1    2.8   2.93    3.0   3.07   3.19   2000    1.0
# y_sim[7]     3.0  2.3e-3    0.1   2.79   2.93    3.0   3.06    3.2   2000    1.0
# y_sim[8]     3.0  2.2e-3    0.1   2.81   2.93    3.0   3.07    3.2   2000    1.0
# y_sim
# y_sim[94]   2.99  2.2e-3    0.1    2.8   2.93   2.99   3.06   3.19   2000    1.0
# y_sim[95]    3.0  2.2e-3    0.1    2.8   2.93    3.0   3.07   3.19   2000    1.0
# y_sim[96]   2.99  2.2e-3    0.1    2.8   2.93    3.0   3.06   3.18   1987    1.0
# y_sim[97]    3.0  2.2e-3    0.1   2.79   2.93   2.99   3.06   3.19   2000    1.0
# y_sim[98]    3.0  2.2e-3    0.1   2.81   2.93    3.0   3.06   3.19   2000    1.0
# y_sim[99]    3.0  2.4e-3    0.1   2.79   2.93    3.0   3.07    3.2   1767    1.0
# lp__      -48.61    0.03   0.76 -50.74 -48.76 -48.32 -48.14 -48.09    606   1.01
#
# Samples were drawn using NUTS at Thu Jan 18 14:42:20 2018.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
beta = fit.extract(permuted=True)['beta']

# %%
# if matplotlib is installed (optional, not required), a visual summary and
# traceplot are available
fit.plot()
plt.show()

# %% [markdown]
# ## Posterior Checks

# %%
y_sim = fit.extract(permuted=True)['y_sim']
y_sim.shape
# Out:
# (2000, 100)

# %%
plt.hist(y_sim[0,:], 12, histtype='step')
# Out:
# (array([ 2.,  2., 10., 10., 20., 23., 13., 11.,  4.,  4.,  0.,  1.]),
#  array([2.75219773, 2.79560069, 2.83900365, 2.88240662, 2.92580958,
#         2.96921254, 3.0126155 , 3.05601847, 3.09942143, 3.14282439,
#         3.18622736, 3.22963032, 3.27303328]),
#  <a list of 1 Patch objects>)

# %% [markdown]
# ### One categorical variable with two levels

# %%
N = 100  # number of data points
beta_true= np.random.normal(0, 1, size=(P,1))
noise_std=0.5
X_train, y_train = build_dataset_linear_model_categorical_1(N, beta_true,noise_std)

# %%
df_train_2=pd.DataFrame(y_train,columns=['y']).join(X_train)
df_train_2
# Out:
#            y  a[a1]  a[a2]
# 0   2.890427    1.0    0.0
# 1   2.567735    0.0    1.0
# 2   2.936032    1.0    0.0
# 3   1.951613    0.0    1.0
# 4   3.628041    1.0    0.0
# 5   2.381102    0.0    1.0
# 6   3.229064    1.0    0.0
# 7   2.255547    0.0    1.0
# 8   3.753637    1.0    0.0
# 9   2.203445    0.0    1.0
# 10  3.749321    1.0    0.0
# 11  1.777965    0.0    1.0
# 12  4.059852    1.0    0.0
# 13  1.905467    0.0    1.0
# 14  3.202289    1.0    0.0
# 15  1.820936    0.0    1.0
# 16  4.126755    1.0    0.0
# 17  2.269117    0.0    1.0
# 18  3.305107    1.0    0.0
# 19  2.000765    0.0    1.0
# 20  3.262077    1.0    0.0
# 21  1.593391    0.0    1.0
# 22  2.782927    1.0    0.0
# 23  1.925701    0.0    1.0
# 24  2.948976    1.0    0.0
# 25  1.062106    0.0    1.0
# 26  3.625812    1.0    0.0
# 27  1.725551    0.0    1.0
# 28  3.015787    1.0    0.0
# 29  1.778209    0.0    1.0
# ..       ...    ...    ...
# 70  3.881967    1.0    0.0
# 71  2.206257    0.0    1.0
# 72  3.543111    1.0    0.0
# 73  2.788483    0.0    1.0
# 74  2.789779    1.0    0.0
# 75  2.200406    0.0    1.0
# 76  3.188138    1.0    0.0
# 77  1.856821    0.0    1.0
# 78  3.476666    1.0    0.0
# 79  3.031879    0.0    1.0
# 80  3.035944    1.0    0.0
# 81  2.174111    0.0    1.0
# 82  3.234788    1.0    0.0
# 83  1.754075    0.0    1.0
# 84  2.915515    1.0    0.0
# 85  1.612767    0.0    1.0
# 86  2.209046    1.0    0.0
# 87  1.604740    0.0    1.0
# 88  2.478085    1.0    0.0
# 89  1.528940    0.0    1.0
# 90  1.992165    1.0    0.0
# 91  2.226949    0.0    1.0
# 92  2.847938    1.0    0.0
# 93  1.545815    0.0    1.0
# 94  3.222518    1.0    0.0
# 95  2.467029    0.0    1.0
# 96  3.511947    1.0    0.0
# 97  1.827970    0.0    1.0
# 98  3.251984    1.0    0.0
# 99  1.575953    0.0    1.0
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Inference

# %%
x=df_train_2[['a[a1]' ,'a[a2]']].apply(lambda x: np.where(x>0)[0][0]+1, axis=1).tolist()
x[:4]
# Out:
# [1, 2, 1, 2]

# %%
y=list(df_train_2['y'].values)

# %%
code = """
functions {
matrix make_X(int N, int D, int[] J) {
    matrix[N, D] X = rep_matrix(0, N, D); #initialize with zeros
    for (i in 1:N){
      X[i, J[i]] = 1.0;
    }
    return X;
  }
}

data {
  int<lower=0> N;
  vector[N] y;
  int x[N];  // group membership variable
}

transformed data { 
  real sigma=0.5;
  int<lower=1> D = max(x); 
  matrix[N, D] X = make_X(N, D, x);
} 

parameters {
  vector[D] beta;
}

model {
  y ~ normal(X * beta, sigma);
}

generated quantities {
   real y_sim[N];
   for(n in 1:N) { 
    y_sim[n] = normal_rng(X[n] * beta, sigma);
   }
}

"""

dat = {'N': N,
       'x': x,
       'y': y}

sm = pystan.StanModel(model_code=code)
fit = sm.sampling(data=dat, iter=2000, chains=4)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_cc681ed11c9cac31db57d618d7e0a1c7 NOW.
# /home/rick/anaconda3/envs/tensorflow/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
print(fit)
# Out:
# Inference for Stan model: anon_model_cc681ed11c9cac31db57d618d7e0a1c7.
# 4 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=4000.
#
#             mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# beta[0]     3.03  1.1e-3   0.07    2.9   2.98   3.03   3.07   3.17   3595    1.0
# beta[1]     1.95  1.2e-3   0.07   1.81    1.9   1.95    2.0   2.09   3592    1.0
# y_sim[0]    3.03  8.0e-3   0.51   2.02   2.69   3.03   3.37   3.99   4000    1.0
# y_sim[1]    1.96  8.2e-3    0.5   0.97   1.63   1.95   2.29   2.95   3707    1.0
# y_sim[2]    3.03  8.0e-3    0.5   2.01   2.69   3.02   3.38    4.0   3970    1.0
# y_sim[3]    1.93  7.9e-3    0.5   0.96    1.6   1.94   2.28   2.91   4000    1.0
# y_sim[4]    3.02  7.9e-3    0.5   2.04   2.68   3.02   3.34   4.02   4000    1.0
# y_sim[5]    1.95  8.1e-3    0.5   0.97   1.61   1.95   2.29   2.93   3866    1.0
# y_sim[6]    3.03  8.2e-3   0.51   2.03   2.69   3.04   3.38   4.04   3905    1.0
# y_sim[7]    1.94  8.0e-3    0.5   0.98    1.6   1.94   2.28   2.93   4000    1.0
# y_sim[8]    3.03  8.1e-3   0.51   2.01   2.69   3.04   3.35   4.03   4000    1.0
2018.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
fit.plot()
plt.show()

# %% [markdown]
# # Edward

# %%
import edward as ed
from edward.models import Normal
import tensorflow as tf
# Out:
# /home/rick/anaconda3/envs/tensorflow/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# /home/rick/anaconda3/envs/tensorflow/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
N = 100  # number of data points
sigma_y = 0.5
sigma_beta=10
D = 2
X = tf.placeholder(tf.float32, [N, D])
beta = Normal(loc=tf.zeros(D), scale=sigma_beta*tf.ones(D))
y = Normal(loc=ed.dot(X, beta), scale=sigma_y*tf.ones(N))

# %%
qbeta = Normal(loc=tf.Variable(tf.random_normal([D])),
            scale=tf.nn.softplus(tf.Variable(tf.random_normal([D]))))

# %%
inference = ed.KLqp({beta: qbeta}, data={X: X_train.values, y: y_train.squeeze()})
inference.run(n_samples=50, n_iter=1000)
# Out:
# /home/rick/anaconda3/envs/tensorflow/lib/python3.6/site-packages/edward/util/random_variables.py:52: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   not np.issubdtype(value.dtype, np.float) and \
# 1000/1000 [100%] ██████████████████████████████ Elapsed: 15s | Loss: 88.111

# %%
qbeta.mean().eval()
# Out:
# array([2.967037 , 1.9478775], dtype=float32)

# %%
qbeta.stddev().eval()
# Out:
# array([0.01746958, 0.01430906], dtype=float32)

# %%
N = 100  # number of data points
beta_true= np.array([[3, 2]]).T
noise_std=0.5
X_test, y_test = build_dataset_linear_model_categorical_1(N, beta_true,noise_std)

# %%
y_post = Normal(loc=ed.dot(X, qbeta), scale=sigma_y*tf.ones(N))

# %%
ed.evaluate('log_likelihood', data={X: X_train.values, y_post: y_train.squeeze().astype(np.float32)})
# Out:
# /home/rick/anaconda3/envs/tensorflow/lib/python3.6/site-packages/edward/util/random_variables.py:52: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   not np.issubdtype(value.dtype, np.float) and \
# -0.79113865

# %%
print("Mean squared error on test data:")
print(ed.evaluate('mean_squared_error', data={X: X_test.values, y_post: y_test.squeeze()}))
# Out:
# Mean squared error on test data:
# /home/rick/anaconda3/envs/tensorflow/lib/python3.6/site-packages/edward/util/random_variables.py:52: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   not np.issubdtype(value.dtype, np.float) and \
# 0.25829014

# %%
T = lambda xs, zs: tf.reduce_mean(xs[y_post])
ty_rep, ty =ed.ppc(T, 
       data={y_post: y_train.squeeze(), 
                X: X_train.values},
       latent_vars={beta: qbeta},
                  n_samples=500)
# Out:
# /home/rick/anaconda3/envs/tensorflow/lib/python3.6/site-packages/edward/util/random_variables.py:52: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   not np.issubdtype(value.dtype, np.float) and \

# %%
ed.ppc_stat_hist_plot(
  ty, ty_rep, stat_name=r'$T \equiv$mean', bins=20)
plt.show()

# %%
ty
# Out:
# array([2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283,
#        2.45324283, 2.45324283, 2.45324283, 2.45324283, 2.45324283])

# %% [markdown]
# ### One categorical variable with 4 levels

# %%
N = 100  # number of data points
beta_true= np.array([[3, 2, 6, 9]]).T
noise_std=0.1
X_train, y_train = build_dataset_linear_model_categorical_1(N, beta_true,noise_std)
df_train_4=pd.DataFrame(y_train,columns=['y']).join(X_train)
df_train_4
# Out:
#            y  a[a1]  a[a2]  a[a3]  a[a4]
